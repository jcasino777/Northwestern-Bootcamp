# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from datetime import date


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
#adjusted latitude to
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#tried this, but came up with duplicates (dead zones w/ not many cities). Code below accounts for dupes
#create random lat_longs
# lat_random = []
# lng_random = []
# loops = 500

# #loop through 500 times, create random lat/longs betweeen possible range
# for x in range(0, loops):
#     lat_random.append(np.random.uniform(min(lat_range), max(lat_range)))
#     lng_random.append(np.random.uniform(min(lng_range), max(lng_range)))

# len(lng_random)

#create list of random cities
# city_list = []

# for x in len:
#     city = citipy.nearest_city(lat_random[x], lng_random[x])
#     city_list.append(city.city_name)

    
# city_df = pd.DataFrame(city_list)
# city_df.columns = ['City']
# city_df['City'].value_counts()

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

lat = []
lng = []
temp = []
cloud = []
humidity = []
Max_Temp = []
Wind_Speed = []
country = []
city_list = []

count = 1
set_count = 1

print('Beginning Data Retrieval')     
print('-----------------------------')
      
#Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        Max_Temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        Wind_Speed.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        city_list += str(city)
        print(f'Processing Record {count} of Set {set_count} | {city}')
        if count >50:
            count = 1
            set_count = set_count + 1
        else:
            count = count + 1
    except KeyError:
        print ('City not found. Skipping...')

print('-----------------------------')
print('Data Retrieval Complete')      
print('-----------------------------')

# response = requests.get(query_url + 'Chicago').json()
# response['main']
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cap-aux-meules
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | naze
# Processing Record 7 of Set 1 | trat
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | rundu
# Processing Record 12 of Set 1 | san cristobal
# Processing Record 13 of Set 1 | aykhal
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | amudat
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | konosha
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | vila franca do campo
# Processing Record 27 of Set 1 | grand-lahou
# Processing Record 28 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 29 of Set 1 | batken
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | rikitea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | punganuru
# Processing Record 37 of Set 1 | solginskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | kamloops
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | kavaratti
# Processing Record 42 of Set 1 | mamallapuram
# Processing Record 43 of Set 1 | brownsville
# Processing Record 44 of Set 1 | north bend
# Processing Record 45 of Set 1 | horasan
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | morros
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | kodiak
# Processing Record 51 of Set 1 | albany
# City not found. Skipping...
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | sorland
# Processing Record 4 of Set 2 | san lazaro
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | takoradi
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | roma
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | honningsvag
# Processing Record 13 of Set 2 | talagante
# Processing Record 14 of Set 2 | rondonopolis
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | wajid
# Processing Record 18 of Set 2 | touros
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | zhigansk
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | ahuimanu
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | westport
# Processing Record 27 of Set 2 | san pedro
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | ban nahin
# Processing Record 31 of Set 2 | bayangol
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | ambilobe
# Processing Record 35 of Set 2 | ankang
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | le port
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | mbanza-ngungu
# City not found. Skipping...
# Processing Record 40 of Set 2 | fort saint james
# Processing Record 41 of Set 2 | greenville
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | umm lajj
# Processing Record 44 of Set 2 | aswan
# Processing Record 45 of Set 2 | labuhan
# Processing Record 46 of Set 2 | bathsheba
# Processing Record 47 of Set 2 | yumbe
# Processing Record 48 of Set 2 | tra vinh
# Processing Record 49 of Set 2 | kutum
# Processing Record 50 of Set 2 | norman wells
# Processing Record 51 of Set 2 | bluff
# Processing Record 1 of Set 3 | los llanos de aridane
# Processing Record 2 of Set 3 | tornio
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | pangnirtung
# Processing Record 5 of Set 3 | igarka
# Processing Record 6 of Set 3 | tasiilaq
# City not found. Skipping...
# Processing Record 7 of Set 3 | oranjestad
# Processing Record 8 of Set 3 | cherskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | alekseyevsk
# Processing Record 12 of Set 3 | tarnogskiy gorodok
# Processing Record 13 of Set 3 | kahului
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | shiyan
# Processing Record 16 of Set 3 | beloha
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | praia
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | la ronge
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | henties bay
# Processing Record 25 of Set 3 | kuito
# City not found. Skipping...
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | ouro preto do oeste
# Processing Record 28 of Set 3 | ngunguru
# Processing Record 29 of Set 3 | terrace
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | hegra
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | maniitsoq
# Processing Record 34 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 3 | nyurba
# Processing Record 36 of Set 3 | karasjok
# Processing Record 37 of Set 3 | palana
# City not found. Skipping...
# Processing Record 38 of Set 3 | surt
# Processing Record 39 of Set 3 | kabare
# Processing Record 40 of Set 3 | ippy
# Processing Record 41 of Set 3 | bonoua
# City not found. Skipping...
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | hokitika
# Processing Record 44 of Set 3 | ahipara
# City not found. Skipping...
# Processing Record 45 of Set 3 | bua yai
# Processing Record 46 of Set 3 | mana
# Processing Record 47 of Set 3 | port lincoln
# Processing Record 48 of Set 3 | izumo
# Processing Record 49 of Set 3 | conakry
# Processing Record 50 of Set 3 | hasaki
# Processing Record 51 of Set 3 | barrow
# Processing Record 1 of Set 4 | launceston
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | la rioja
# Processing Record 4 of Set 4 | coria
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | campbell river
# Processing Record 7 of Set 4 | areosa
# City not found. Skipping...
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | barra patuca
# Processing Record 10 of Set 4 | kushima
# Processing Record 11 of Set 4 | liwale
# Processing Record 12 of Set 4 | turan
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | saint anthony
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | alexandria
# Processing Record 18 of Set 4 | algiers
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 4 | goderich
# City not found. Skipping...
# Processing Record 20 of Set 4 | morondava
# Processing Record 21 of Set 4 | elko
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | payo
# City not found. Skipping...
# Processing Record 24 of Set 4 | orlik
# Processing Record 25 of Set 4 | toktogul
# Processing Record 26 of Set 4 | dikson
# Processing Record 27 of Set 4 | vallenar
# City not found. Skipping...
# Processing Record 28 of Set 4 | isangel
# Processing Record 29 of Set 4 | lalsk
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | sept-iles
# City not found. Skipping...
# Processing Record 32 of Set 4 | xinpu
# Processing Record 33 of Set 4 | okha
# City not found. Skipping...
# Processing Record 34 of Set 4 | yulara
# Processing Record 35 of Set 4 | mentakab
# Processing Record 36 of Set 4 | berlevag
# Processing Record 37 of Set 4 | usogorsk
# Processing Record 38 of Set 4 | kavieng
# Processing Record 39 of Set 4 | chulym
# Processing Record 40 of Set 4 | comodoro rivadavia
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | luanda
# Processing Record 43 of Set 4 | siddipet
# Processing Record 44 of Set 4 | coahuayana
# Processing Record 45 of Set 4 | ust-maya
# Processing Record 46 of Set 4 | nara
# Processing Record 47 of Set 4 | cap malheureux
# Processing Record 48 of Set 4 | klyuchi
# Processing Record 49 of Set 4 | tezu
# Processing Record 50 of Set 4 | nadym
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 51 of Set 4 | zholymbet
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | cooma
# Processing Record 3 of Set 5 | nome
# Processing Record 4 of Set 5 | arroyo
# Processing Record 5 of Set 5 | dickinson
# Processing Record 6 of Set 5 | kyela
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | nanortalik
# City not found. Skipping...
# Processing Record 9 of Set 5 | vilyuysk
# Processing Record 10 of Set 5 | jumla
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | caluquembe
# Processing Record 13 of Set 5 | ternate
# City not found. Skipping...
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | mercedes
# City not found. Skipping...
# Processing Record 16 of Set 5 | teguise
# Processing Record 17 of Set 5 | bereda
# Processing Record 18 of Set 5 | okhotsk
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | gizo
# Processing Record 21 of Set 5 | pennathur
# Processing Record 22 of Set 5 | glyadyanskoye
# Processing Record 23 of Set 5 | piney green
# Processing Record 24 of Set 5 | sioux lookout
# City not found. Skipping...
# Processing Record 25 of Set 5 | grand-santi
# Processing Record 26 of Set 5 | patiya
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | saurimo
# Processing Record 29 of Set 5 | reconquista
# City not found. Skipping...
# Processing Record 30 of Set 5 | soyo
# Processing Record 31 of Set 5 | tashla
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | port hedland
# Processing Record 34 of Set 5 | tonantins
# Processing Record 35 of Set 5 | sterling
# Processing Record 36 of Set 5 | alakurtti
# Processing Record 37 of Set 5 | kalagarh
# Processing Record 38 of Set 5 | sao benedito do rio preto
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | olinda
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | meulaboh
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | shakhunya
# Processing Record 45 of Set 5 | pagudpud
# Processing Record 46 of Set 5 | anchorage
# Processing Record 47 of Set 5 | riberalta
# City not found. Skipping...
# Processing Record 48 of Set 5 | ust-barguzin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | antalaha
# Processing Record 51 of Set 5 | duku
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | gorin
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | nevel
# Processing Record 7 of Set 6 | prince rupert
# Processing Record 8 of Set 6 | manyana
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | bilma
# City not found. Skipping...
# Processing Record 11 of Set 6 | mangai
# City not found. Skipping...
# Processing Record 12 of Set 6 | shiojiri
# Processing Record 13 of Set 6 | pangoa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | denpasar
# Processing Record 17 of Set 6 | gisborne
# City not found. Skipping...
# Processing Record 18 of Set 6 | taoudenni
# Processing Record 19 of Set 6 | mopti
# Processing Record 20 of Set 6 | uberlandia
# City not found. Skipping...
# Processing Record 21 of Set 6 | kisangani
# Processing Record 22 of Set 6 | kulachi
# Processing Record 23 of Set 6 | anadyr
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | visby
# City not found. Skipping...
# Processing Record 26 of Set 6 | aksu
# Processing Record 27 of Set 6 | xai-xai
# Processing Record 28 of Set 6 | yuci
# Processing Record 29 of Set 6 | roblin
# Processing Record 30 of Set 6 | tarata
# Processing Record 31 of Set 6 | pangody
# Processing Record 32 of Set 6 | liptovsky hradok
# Processing Record 33 of Set 6 | baijiantan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 6 | luwuk
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | linda
# Processing Record 37 of Set 6 | cosamaloapan
# Processing Record 38 of Set 6 | ayia galini
# Processing Record 39 of Set 6 | clifton
# Processing Record 40 of Set 6 | itarema
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | dromolaxia
# Processing Record 43 of Set 6 | pineville
# City not found. Skipping...
# Processing Record 44 of Set 6 | waingapu
# Processing Record 45 of Set 6 | birjand
# Processing Record 46 of Set 6 | fort nelson
# Processing Record 47 of Set 6 | chara
# Processing Record 48 of Set 6 | torbay
# City not found. Skipping...
# Processing Record 49 of Set 6 | embrach
# Processing Record 50 of Set 6 | raudeberg
# Processing Record 51 of Set 6 | kaeo
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 2 of Set 7 | rio tercero
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | carroll
# Processing Record 6 of Set 7 | acajutla
# Processing Record 7 of Set 7 | pozo colorado
# Processing Record 8 of Set 7 | yenangyaung
# Processing Record 9 of Set 7 | rosita
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | glendive
# Processing Record 12 of Set 7 | mandalay
# Processing Record 13 of Set 7 | ndjole
# Processing Record 14 of Set 7 | houma
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | guerrero negro
# Processing Record 18 of Set 7 | cody
# Processing Record 19 of Set 7 | sola
# City not found. Skipping...
# Processing Record 20 of Set 7 | kamenka
# Processing Record 21 of Set 7 | panaba
# Processing Record 22 of Set 7 | miandrivazo
# Processing Record 23 of Set 7 | ocean city
# Processing Record 24 of Set 7 | price
# Processing Record 25 of Set 7 | christchurch
# Processing Record 26 of Set 7 | fortuna
# Processing Record 27 of Set 7 | chimore
# Processing Record 28 of Set 7 | rafai
# Processing Record 29 of Set 7 | itoman
# Processing Record 30 of Set 7 | alto piquiri
# Processing Record 31 of Set 7 | veraval
# Processing Record 32 of Set 7 | zhezkazgan
# Processing Record 33 of Set 7 | ilulissat
# Processing Record 34 of Set 7 | portland
# Processing Record 35 of Set 7 | kastamonu
# Processing Record 36 of Set 7 | borazjan
# Processing Record 37 of Set 7 | flin flon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 7 | carbondale
# Processing Record 39 of Set 7 | saint-joseph
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | iralaya
# Processing Record 42 of Set 7 | shemonaikha
# Processing Record 43 of Set 7 | grindavik
# City not found. Skipping...
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | hambantota
# Processing Record 46 of Set 7 | lingao
# Processing Record 47 of Set 7 | lahat
# Processing Record 48 of Set 7 | betsiamites
# Processing Record 49 of Set 7 | ronneby
# Processing Record 50 of Set 7 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 51 of Set 7 | yar-sale
# Processing Record 1 of Set 8 | dubbo
# Processing Record 2 of Set 8 | mayor pablo lagerenza
# Processing Record 3 of Set 8 | corrales
# Processing Record 4 of Set 8 | waiouru
# Processing Record 5 of Set 8 | peniche
# Processing Record 6 of Set 8 | banikoara
# Processing Record 7 of Set 8 | badou
# Processing Record 8 of Set 8 | adrar
# Processing Record 9 of Set 8 | plettenberg bay
# Processing Record 10 of Set 8 | puro
# Processing Record 11 of Set 8 | tshela
# City not found. Skipping...
# Processing Record 12 of Set 8 | huarmey
# City not found. Skipping...
# Processing Record 13 of Set 8 | vardo
# City not found. Skipping...
# Processing Record 14 of Set 8 | diamantino
# Processing Record 15 of Set 8 | ambon
# City not found. Skipping...
# Processing Record 16 of Set 8 | cabinda
# Processing Record 17 of Set 8 | acapulco
# Processing Record 18 of Set 8 | kirakira
# City not found. Skipping...
# Processing Record 19 of Set 8 | tutoia
# Processing Record 20 of Set 8 | novyy urengoy
# Processing Record 21 of Set 8 | ambulu
# Processing Record 22 of Set 8 | pala
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | altay
# Processing Record 25 of Set 8 | kargasok
# Processing Record 26 of Set 8 | sisimiut
# Processing Record 27 of Set 8 | kampot
# Processing Record 28 of Set 8 | tabou
# Processing Record 29 of Set 8 | crib point
# City not found. Skipping...
# Processing Record 30 of Set 8 | aksarka
# Processing Record 31 of Set 8 | tocopilla
# Processing Record 32 of Set 8 | kalabo
# Processing Record 33 of Set 8 | daru
# Processing Record 34 of Set 8 | bilibino
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | sinegorye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 8 | fayetteville
# Processing Record 38 of Set 8 | macusani
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | marfino
# Processing Record 41 of Set 8 | san pietro vernotico
# Processing Record 42 of Set 8 | hobyo
# Processing Record 43 of Set 8 | nova vicosa
# Processing Record 44 of Set 8 | port moresby
# Processing Record 45 of Set 8 | hellin
# Processing Record 46 of Set 8 | gazojak
# Processing Record 47 of Set 8 | camacupa
# City not found. Skipping...
# Processing Record 48 of Set 8 | port macquarie
# Processing Record 49 of Set 8 | dzilam gonzalez
# Processing Record 50 of Set 8 | santa cruz
# City not found. Skipping...
# Processing Record 51 of Set 8 | adelanto
# Processing Record 1 of Set 9 | ballina
# Processing Record 2 of Set 9 | udachnyy
# Processing Record 3 of Set 9 | shenjiamen
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | bad laasphe
# Processing Record 6 of Set 9 | nelson bay
# Processing Record 7 of Set 9 | santiago del estero
# Processing Record 8 of Set 9 | imbituba
# City not found. Skipping...
# Processing Record 9 of Set 9 | mopipi
# Processing Record 10 of Set 9 | nhulunbuy
# Processing Record 11 of Set 9 | betare oya
# Processing Record 12 of Set 9 | santa maria
# Processing Record 13 of Set 9 | half moon bay
# Processing Record 14 of Set 9 | aguimes
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | zhangjiakou
# Processing Record 17 of Set 9 | atar
# Processing Record 18 of Set 9 | buala
# Processing Record 19 of Set 9 | poli
# Processing Record 20 of Set 9 | norrkoping
# Processing Record 21 of Set 9 | kjollefjord
# Processing Record 22 of Set 9 | tarakan
# Processing Record 23 of Set 9 | njombe
# Processing Record 24 of Set 9 | hovd
# Processing Record 25 of Set 9 | thinadhoo
# Processing Record 26 of Set 9 | gudari
# Processing Record 27 of Set 9 | slave lake
# Processing Record 28 of Set 9 | kushiro
# Processing Record 29 of Set 9 | guisa
# Processing Record 30 of Set 9 | hami
# Processing Record 31 of Set 9 | trujillo
# Processing Record 32 of Set 9 | waslala
# Processing Record 33 of Set 9 | ponta delgada
# Processing Record 34 of Set 9 | matagami
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | alugan
# Processing Record 37 of Set 9 | orje
# Processing Record 38 of Set 9 | maningrida
# Processing Record 39 of Set 9 | kozhevnikovo
# Processing Record 40 of Set 9 | mabaruma
# Processing Record 41 of Set 9 | hamilton
# Processing Record 42 of Set 9 | frontera
# Processing Record 43 of Set 9 | tual
# Processing Record 44 of Set 9 | los reyes
# Processing Record 45 of Set 9 | hirara
# Processing Record 46 of Set 9 | karratha
# Processing Record 47 of Set 9 | puerto asis
# City not found. Skipping...
# Processing Record 48 of Set 9 | cayenne
# Processing Record 49 of Set 9 | pontypool
# Processing Record 50 of Set 9 | longyan
# Processing Record 51 of Set 9 | calama
# Processing Record 1 of Set 10 | farrukhnagar
# Processing Record 2 of Set 10 | sulangan
# Processing Record 3 of Set 10 | russell
# Processing Record 4 of Set 10 | mocuba
# Processing Record 5 of Set 10 | homer
# Processing Record 6 of Set 10 | eureka
# Processing Record 7 of Set 10 | key west
# Processing Record 8 of Set 10 | escarcega
# Processing Record 9 of Set 10 | abu samrah
# Processing Record 10 of Set 10 | toba
# Processing Record 11 of Set 10 | lakes entrance
# Processing Record 12 of Set 10 | hailar
# Processing Record 13 of Set 10 | hostotipaquillo
# Processing Record 14 of Set 10 | srednekolymsk
# Processing Record 15 of Set 10 | beian
# City not found. Skipping...
# Processing Record 16 of Set 10 | mahibadhoo
# Processing Record 17 of Set 10 | codrington
# Processing Record 18 of Set 10 | rovaniemi
# Processing Record 19 of Set 10 | mangrol
# Processing Record 20 of Set 10 | ugoofaaru
# Processing Record 21 of Set 10 | pangkalanbuun
# City not found. Skipping...
# Processing Record 22 of Set 10 | nantucket
# Processing Record 23 of Set 10 | gladstone
# Processing Record 24 of Set 10 | agnibilekrou
# Processing Record 25 of Set 10 | picota
# Processing Record 26 of Set 10 | mazarron
# Processing Record 27 of Set 10 | laukaa
# Processing Record 28 of Set 10 | srivardhan
# Processing Record 29 of Set 10 | almaznyy
# Processing Record 30 of Set 10 | amalapuram

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
summary_df = pd.DataFrame(list(zip(city_list,cloud,country,humidity,lat,lng,Max_Temp,Wind_Speed)),
                          columns=['City','Cloudiness','Country','Humidity','Lat','Lng','Max Temp','Wind Speed'])

summary_df.to_csv(output_data_file)

summary_df.head()
# Out:
#          City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0     mataura          76      ZA       100 -33.02   27.91     23.18
# 1  sao filipe          56      RU        77  61.28  108.01     -3.57
# 2        roma          75      CA        59  62.45 -114.38      2.22
# 3       abhar          40      CA        71  47.66  -52.73     10.00
# 4       mrirt          68      PF       100 -23.12 -134.97     24.93
#
#    Wind Speed
# 0        2.55
# 1        2.95
# 2        7.20
# 3        5.10
# 4        8.30

# %%
summary_df.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(summary_df["Lat"], summary_df["Max Temp"]*(9/5)+32, marker="o")

today = str(date.today())
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Temperature_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(summary_df["Lat"], summary_df["Humidity"], marker="o")

today = str(date.today())
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({today})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(0,105)
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(summary_df["Lat"], summary_df["Cloudiness"], marker="o")

today = str(date.today())
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(0,105)
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(summary_df["Lat"], summary_df["Wind Speed"]/0.621371, marker="o")

today = str(date.today())
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.ylabel("Windspeed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()
